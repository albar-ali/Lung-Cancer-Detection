# %%
import pandas as pd
df=pd.read_csv("ClinicalDataset.csv")
df.head()
# Out:
#   Patient Id  Age  Gender  LUNG CANCER  Air Pollution  Alcohol use  \
# 0         P1   33       1            1              2            4
# 1         P2   17       1            1              3            1
# 2         P3   35       1            0              4            5
# 3         P4   37       1            1              7            7
# 4         P5   46       1            1              6            8
#
#    Dust Allergy  OccuPational Hazards  Genetic Risk  Balanced Diet  ...  \
# 0             5                     4             3              2  ...
# 1             5                     3             4              2  ...
# 2             6                     5             5              6  ...
# 3             7                     7             6              7  ...
# 4             7                     7             7              7  ...
#
#    CHRONIC DISEASE  ALLERGY  ALCOHOL CONSUMING  SWALLOWING DIFFICULTY  \
# ...

# %%
df['LUNG CANCER'].value_counts()
# Out:
# LUNG CANCER
# 1    1200
# 0     800
# Name: count, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Patient Id',
#  'Age',
#  'Gender',
#  'LUNG CANCER',
#  'Air Pollution',
#  'Alcohol use',
#  'Dust Allergy',
#  'OccuPational Hazards',
#  'Genetic Risk',
#  'Balanced Diet',
#  'Obesity',
#  'Smoking',
#  'Passive Smoker',
#  'Chest Pain',
#  'Coughing of Blood',
#  'Fatigue',
#  'Weight Loss',
#  'Shortness of Breath',
#  'Wheezing',
#  'Swallowing Difficulty',
#  'Clubbing of Finger Nails',
#  'Frequent Cold',
#  'Dry Cough',
#  'Snoring',
#  'YELLOW FINGERS',
#  'ANXIETY',
#  'PEER PRESSURE',
#  'CHRONIC DISEASE',
#  'ALLERGY',
#  'ALCOHOL CONSUMING',
#  'SWALLOWING DIFFICULTY',
#  'HEMOGLOBIN',
#  'WHITE BLOOD CELLS',
#  'PLATELETS',
#  'RED BLOOD CELLS',
#  'CHOLESTEROL',
#  'GLUCOSE']
